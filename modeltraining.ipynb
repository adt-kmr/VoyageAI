# %%
#training dataset in finalclusteringdataset using kmeans
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
#load the dataset
dataset=pd.read_csv('finalclusteringdataset.csv')
dataset.head()
# Out:
#    trip_frequency  average_booking_value  destination_diversity  \
# 0       -0.908427              -0.649795               0.779566
# 1       -0.452339                    NaN               0.779566
# 2       -0.452339              -0.490367              -1.156358
# 3        0.003749              -0.391374              -1.156358
# 4       -0.452339              -0.241383               0.779566
#
#    session_duration  search_behavior
# 0          0.220535        -1.231300
# 1         -0.212597         1.220781
# 2         -0.444734        -0.005260
# 3         -0.969480         1.220781
# 4          0.518060        -0.005260

# %%
X = dataset[['trip_frequency', 'average_booking_value', 'destination_diversity', 'session_duration', 'search_behavior']]

# %%
scaler=StandardScaler()
X_fit=scaler.fit_transform(X)

# %%
#training models using kmeans
kmeans=KMeans(n_clusters=5,random_state=42)
df["Cluster"] = kmeans.fit_predict(X)
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
#visualize the clusters
plt.title('KMeans Clustering')  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 3
#       1 #training models using kmeans
#       2 kmeans=KMeans(n_clusters=5,random_state=42)
# ----> 3 kmeans.fit(X)
#       4 print(classification_report(y_test,y_pred))
#       5 print(confusion_matrix(y_test,y_pred))
#
# File c:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 3
#       1 #selecting features for clustering Use KMeans(Partition Based Dataset)
#       2 model=KMeans(n_clusters=5, random_state=42)
# ----> 3 model.fit(dataset[['trip_frequency', 'average_booking_value', 'destination_diversity', 'session_duration']])
#
# File c:\Users\vansh\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
KMeans.fit(X)

# %%
label_predict=KMeans.predict(X)
